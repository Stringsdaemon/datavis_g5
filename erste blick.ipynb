# %%
import pandas as pd

# %%
data = pd.read_csv('google_clean_v3.csv')
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres         Current Ver   Android Ver  \
# 0               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
# Find duplicate apps
duplicate_apps = data[data.duplicated(subset=["App"])]  # keep=False shows all duplicates

# Display the duplicate entries
print(f"Found {duplicate_apps.shape[0]} duplicate entries in the 'App' column.")
duplicate_apps
# Show the first few duplicates
# Out:
# Found 1181 duplicate entries in the 'App' column.
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
# ...

# %%
app_name = "10 Best Foods for You"  # Replace with the actual app name you want to search for
data[data["App"] == app_name]
# Out:
#                         App            Category  Rating  Reviews    Size  \
# 1393  10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490  3800.0
# 1407  10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490  3800.0
#
#       Installs  Type  Price Content Rating            Genres Current Ver  \
# 1393    500000  Free    0.0   Everyone 10+  Health & Fitness         1.9
# 1407    500000  Free    0.0   Everyone 10+  Health & Fitness         1.9
#
#        Android Ver  Day_last_update  month_last_update  year_last_update  \
# 1393  2.3.3 and up               17                  2              2017
# 1407  2.3.3 and up               17                  2              2017
#
#      Last_Updated
# 1393   2017-02-17
# 1407   2017-02-17

# %%
# Remove duplicates, keeping the first occurrence
df_cleaned = data.drop_duplicates(subset=["App"], keep="first")

# Save the cleaned dataset
df_cleaned.to_csv("google_clean_v3.csv", index=False)

print(f"Duplicates removed! The cleaned dataset now has {df_cleaned.shape[0]} entries.")
# Out:
# Duplicates removed! The cleaned dataset now has 9659 entries.
